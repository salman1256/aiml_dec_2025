# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
resumes=[
          'Experienced software engineer with expertise in Web development and SQL Server',
          'Java Developer skilled in spring Boot, SQL and Microservices',
          'Dot net Developer with experience in asp.net SQL, Microservices',
          'Developer  with python, Machine Learning NLP and pandas,Deep Learning , visualization',
          'Frond End Developer with HTML, CSS-3, JavaScript and React',
          'Deep Learning specialist experience in python, nlp and deep learning',
         ]

# %%
job_descriptions=['Looking for Python Developer with experience in deep learning and nlp']

# %%
documents=resumes+job_descriptions

# %%
documents
# Out:
# ['Experienced software engineer with expertise in Web development and SQL Server',
#  'Java Developer skilled in spring Boot, SQL and Microservices',
#  'Dot net Developer with experience in asp.net SQL, Microservices',
#  'Developer  with python, Machine Learning NLP and pandas,Deep Learning , visualization',
#  'Frond End Developer with HTML, CSS-3, JavaScript and React',
#  'Deep Learning specialist experience in python, nlp and deep learning',
#  'Looking for Python Developer with experience in deep learning and nlp']

# %%
vectorizer=TfidfVectorizer()
tfidf_matrix=vectorizer.fit_transform(documents)

# %%
#compare resumes with job description
cosine_similarities=cosine_similarity(tfidf_matrix[:len(resumes)],tfidf_matrix[len(resumes):])

# %%
#Display score
for i,similarity_score in enumerate(cosine_similarities):
  print(f"Resume {i+1}: Similarity Score = {similarity_score[0]:.2f}")
# Out:
# Resume 1: Similarity Score = 0.12
# Resume 2: Similarity Score = 0.14
# Resume 3: Similarity Score = 0.20
# Resume 4: Similarity Score = 0.52
# Resume 5: Similarity Score = 0.13
# Resume 6: Similarity Score = 0.64

# %%
#Email Routing

# %%
#Import all required libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df=pd.read_csv('/content/sample_data/support_ticket_routing.csv')

# %%
df
# Out:
#    TicketID  Department                                        Description
# 0       101  IT Support  Laptop not starting VPN not connecting email i...
# 1       102          HR  Leave balance salary slip update and attendanc...
# 2       103     Finance  Invoice mismatch payment pending and tax deduc...
# 3       104       Sales  Client asking about product pricing discount a...
# 4       105  IT Support  System slow password reset software installati...
# 5       106          HR  Payslip missing salary not credited PF deducti...

# %%
#new_email : we will take and check it is for which department
user_email=input("Enter the email: ")
# Out:
# Enter the email: My Salary not credited yet, Please update the reason

# %%
documents=df['Description'].tolist()+[user_email]

# %%
vectorizer=TfidfVectorizer(stop_words='english')
X=vectorizer.fit_transform(documents)

# %%
similarity_matrix=cosine_similarity(X[:-1],X[-1])
df['SimilartyScore']=similarity_matrix.flatten()

# %%
print(df[['TicketID','Department','SimilartyScore']])
# Out:
#    TicketID  Department  SimilartyScore
# 0       101  IT Support        0.000000
# 1       102          HR        0.294345
# 2       103     Finance        0.000000
# 3       104       Sales        0.000000
# 4       105  IT Support        0.000000
# 5       106          HR        0.289664

# %%
best_ticket=df.loc[df['SimilartyScore'].idxmax()]
print('Send this email to Department',best_ticket['Department'])
# Out:
# Send this email to Department HR

# %% [markdown]
# ### Use following dataset and write one NLP example to predict whether an email is a SPAM or NOT SPAM

# %%
dataset={
    'EmailText':['Win a free IPhone click the link below',
                 'Limited time offer claim your prize of 20000 USD',
                 'Meeting Schedule for tommorow',
                 'Please find attached business report',
                 'Congratulation!!! your have won a lottery of RM 40000',
                 'Let us meet and discussed project',
                 'Your name came in lucky draw send account details for getting free money'
                 ],
    'IsSpam':[1,1,0,0,1,0,1]  #Spam =1 , Not Spam=0
}

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#                                            EmailText  IsSpam
# 0             Win a free IPhone click the link below       1
# 1   Limited time offer claim your prize of 20000 USD       1
# 2                      Meeting Schedule for tommorow       0
# 3               Please find attached business report       0
# 4  Congratulation!!! your have won a lottery of R...       1
# 5                  Let us meet and discussed project       0
# 6  Your name came in lucky draw send account deta...       1

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))
lemmatizer=WordNetLemmatizer()

# %%
#Text Cleaning and Lemmatization
def clean_text(text):
  text=text.lower()
  text=re.sub(r'[^a-zA-Z0-9\s]','',text)
  words=text.split()
  words=[lemmatizer.lemmatize(word) for word in words if word not in stop_words]
  cleaned_text=' '.join(words)
  return cleaned_text

# %%
df['CleanedEmail']=df['EmailText'].apply(clean_text)

# %%
df
# Out:
#                                            EmailText  IsSpam  \
# 0             Win a free IPhone click the link below       1
# 1   Limited time offer claim your prize of 20000 USD       1
# 2                      Meeting Schedule for tommorow       0
# 3               Please find attached business report       0
# 4  Congratulation!!! your have won a lottery of R...       1
# 5                  Let us meet and discussed project       0
# 6  Your name came in lucky draw send account deta...       1
#
#                                         CleanedEmail
# 0                         win free iphone click link
# 1           limited time offer claim prize 20000 usd
# 2                          meeting schedule tommorow
# 3               please find attached business report
# 4                    congratulation lottery rm 40000
# 5                       let u meet discussed project
# 6  name came lucky draw send account detail getti...

# %%
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(df['CleanedEmail'])
y=df['IsSpam']

# %%
#Train Test Split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
print('Training Data')
print(X_train.shape)
print(y_train.shape)
print('Testing Data')
print(X_test.shape)
print(y_test.shape)
# Out:
# Training Data
# (6, 37)
# (6,)
# Testing Data
# (1, 37)
# (1,)

# %%
model =LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
print('Actual values ',y_test.values)
print('Predicted values ',y_pred)
# Out:
# Actual values  [1]
# Predicted values  [1]

# %%
print('Accuracy',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
#Predict a new email is spam or not a spam using this model
new_email='Congratulation!!! your have won a lottery of RM 40000'
cleaned_new_email=clean_text(new_email)
vectorized_new_email=vectorizer.transform([cleaned_new_email])
prediction=model.predict(vectorized_new_email)
if prediction[0]==1:
  print(f'{new_email} is likely: ','Spam')
else:
  print(f'{new_email} is likely: ','Not Spam')
# Out:
# Congratulation!!! your have won a lottery of RM 40000 is likely:  Spam

# %%
user_email=input("enter your email")
cleaned_user_email=clean_text(user_email)
vectorized_user_email=vectorizer.transform([cleaned_user_email])
prediction=model.predict(vectorized_user_email)
if prediction[0]==1:
  print(f'{user_email} is likely: ','Spam')

else:
  print(f'{user_email} is likely: ','Not Spam')
# Out:
# enter your emailLets celebrate birthday of collegue
# Lets celebrate birthday of collegue is likely:  Not Spam
