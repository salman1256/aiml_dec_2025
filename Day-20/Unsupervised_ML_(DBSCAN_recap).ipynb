# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
df=pd.read_csv('/content/sample_data/product_quality.csv')

# %%
df
# Out:
#      Length_mm  Weight_g
# 0       100.99    246.88
# 1        99.72    247.22
# 2       101.30    246.81
# 3       103.05    255.95
# 4        99.53    257.10
# ..         ...       ...
# 995     185.32    191.25
# 996     178.23    278.68
# 997     153.88    310.12
# 998     129.34    546.35
# 999     173.10    267.74
#
# [1000 rows x 2 columns]

# %%
scaler=StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
from scipy.spatial import distance
from sklearn import neighbors
neighbors=neighbors.NearestNeighbors(n_neighbors=10)
neighbors_fit=neighbors.fit(df_scaled)
distance,indices=neighbors_fit.kneighbors(df_scaled)
distance=np.sort(distance,axis=0)
distance=distance[:,1]
plt.figure(figsize=(10,5))
plt.plot(distance)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %%
dbscan=DBSCAN(eps=0.5,min_samples=10)

# %%
df['Cluster']=dbscan.fit_predict(df_scaled)

# %%
df
# Out:
#      Length_mm  Weight_g  Cluster
# 0       100.99    246.88        0
# 1        99.72    247.22        0
# 2       101.30    246.81        0
# 3       103.05    255.95        0
# 4        99.53    257.10        0
# ..         ...       ...      ...
# 995     185.32    191.25       -1
# 996     178.23    278.68       -1
# 997     153.88    310.12       -1
# 998     129.34    546.35       -1
# 999     173.10    267.74       -1
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#      Length_mm  Weight_g  Cluster
# 0       100.99    246.88        0
# 1        99.72    247.22        0
# 2       101.30    246.81        0
# 3       103.05    255.95        0
# 4        99.53    257.10        0
# ..         ...       ...      ...
# 995     185.32    191.25       -1
# 996     178.23    278.68       -1
# 997     153.88    310.12       -1
# 998     129.34    546.35       -1
# 999     173.10    267.74       -1
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['Length_mm'],df['Weight_g'],c=df['Cluster'])
plt.xlabel('Length_mm')
plt.ylabel('Weight_g')
plt.show()
