# %% [markdown]
# **Panads is a python library it is used fo data anlaysis, data cleaning and data manipulation**
# * import pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
# Create Series using pandas
pd_series=pd.Series([1,2,3,4,5])
pd_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df=pd.DataFrame(np.random.rand(100,5))
df
# Out:
#            0         1         2         3         4
# 0   0.849677  0.908626  0.127445  0.914261  0.275301
# 1   0.284352  0.408419  0.437762  0.586530  0.502967
# 2   0.910679  0.746669  0.416769  0.741214  0.706307
# 3   0.881377  0.358772  0.181874  0.245655  0.612589
# 4   0.213571  0.917524  0.999343  0.799102  0.652353
# ..       ...       ...       ...       ...       ...
# 95  0.133951  0.693381  0.069909  0.507604  0.751502
# 96  0.320518  0.828176  0.469162  0.455700  0.341620
# 97  0.705338  0.674843  0.971547  0.593818  0.331025
# 98  0.139777  0.936517  0.464060  0.287593  0.130519
# 99  0.384153  0.008685  0.965646  0.575889  0.109301
#
# [100 rows x 5 columns]

# %%
data={
    'Student Name':['Sam','Ravi','Amit','Vijay','Alina','Neha','Vini','Deep','Anam','Jai','Anil','Abhi'],
    'Student Marks':[45,90,36,45,55,89,90,90,75,98,90,78]

}

# %%
df=pd.DataFrame(data)
df
# Out:
#    Student Name  Student Marks
# 0           Sam             45
# 1          Ravi             90
# 2          Amit             36
# 3         Vijay             45
# 4         Alina             55
# 5          Neha             89
# 6          Vini             90
# 7          Deep             90
# 8          Anam             75
# 9           Jai             98
# 10         Anil             90
# 11         Abhi             78

# %%
df.head() #Return the first n rows.This function returns the first n rows for the object basedon position.
# Out:
#   Student Name  Student Marks
# 0          Sam             45
# 1         Ravi             90
# 2         Amit             36
# 3        Vijay             45
# 4        Alina             55

# %%
df.head(2)
# Out:
#   Student Name  Student Marks
# 0          Sam             45
# 1         Ravi             90

# %%
df.tail() #Return the last n rows. default last 5
# Out:
#    Student Name  Student Marks
# 7          Deep             90
# 8          Anam             75
# 9           Jai             98
# 10         Anil             90
# 11         Abhi             78

# %%
df.tail(3)
# Out:
#    Student Name  Student Marks
# 9           Jai             98
# 10         Anil             90
# 11         Abhi             78

# %%
df.info()
#Print a concise summary of a DataFrame.This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student Name   12 non-null     object
#  1   Student Marks  12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
df.describe() #Generate descriptive statistics.
# Out:
#        Student Marks
# count      12.000000
# mean       73.416667
# std        22.001894
# min        36.000000
# 25%        52.500000
# 50%        83.500000
# 75%        90.000000
# max        98.000000

# %%
df.shape # return number of rows and number of columns
# Out:
# (12, 2)

# %%
df.dtypes
# Out:
# Student Name     object
# Student Marks     int64
# dtype: object

# %%
df['Student Name']
# Out:
# 0       Sam
# 1      Ravi
# 2      Amit
# 3     Vijay
# 4     Alina
# 5      Neha
# 6      Vini
# 7      Deep
# 8      Anam
# 9       Jai
# 10     Anil
# 11     Abhi
# Name: Student Name, dtype: object

# %%
df['Student Marks']
# Out:
# 0     45
# 1     90
# 2     36
# 3     45
# 4     55
# 5     89
# 6     90
# 7     90
# 8     75
# 9     98
# 10    90
# 11    78
# Name: Student Marks, dtype: int64

# %%
df[['Student Name','Student Marks']]
# Out:
#    Student Name  Student Marks
# 0           Sam             45
# 1          Ravi             90
# 2          Amit             36
# 3         Vijay             45
# 4         Alina             55
# 5          Neha             89
# 6          Vini             90
# 7          Deep             90
# 8          Anam             75
# 9           Jai             98
# 10         Anil             90
# 11         Abhi             78

# %%
df.loc[0]
# Out:
# Student Name     Sam
# Student Marks     45
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#   Student Name  Student Marks
# 0          Sam             45
# 1         Ravi             90
# 2         Amit             36

# %%
df.loc[:3]
# Out:
#   Student Name  Student Marks
# 0          Sam             45
# 1         Ravi             90
# 2         Amit             36
# 3        Vijay             45

# %%
df.loc[:3,['Student Name']]
# Out:
#   Student Name
# 0          Sam
# 1         Ravi
# 2         Amit
# 3        Vijay

# %%
df.loc[:3,['Student Marks']]
# Out:
#    Student Marks
# 0             45
# 1             90
# 2             36
# 3             45

# %%
df.loc[df['Student Marks']>=90,['Student Name','Student Marks']]  #Conditional Selection using loc :Label based
# Out:
#    Student Name  Student Marks
# 1          Ravi             90
# 6          Vini             90
# 7          Deep             90
# 9           Jai             98
# 10         Anil             90

# %%
#loc:Label based selection
#df.loc[row_label,column_label]

# %%
# iloc:Integer based selection
# df.iloc[row_index,column_index]

# %%
df.iloc[0]
# Out:
# Student Name     Sam
# Student Marks     45
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#   Student Name  Student Marks
# 0          Sam             45
# 1         Ravi             90

# %%
# select specific rows and column
df.iloc[0:3,0:1]
# Out:
#   Student Name
# 0          Sam
# 1         Ravi
# 2         Amit

# %%
df
# Out:
#    Student Name  Student Marks
# 0           Sam             45
# 1          Ravi             90
# 2          Amit             36
# 3         Vijay             45
# 4         Alina             55
# 5          Neha             89
# 6          Vini             90
# 7          Deep             90
# 8          Anam             75
# 9           Jai             98
# 10         Anil             90
# 11         Abhi             78

# %%
# Adding columns in existing dataframe
df['Student Gender']=['M','M','M','M','F','F','F','F','M','M','M','M']

# %%
df
# Out:
#    Student Name  Student Marks Student Gender
# 0           Sam             45              M
# 1          Ravi             90              M
# 2          Amit             36              M
# 3         Vijay             45              M
# 4         Alina             55              F
# 5          Neha             89              F
# 6          Vini             90              F
# 7          Deep             90              F
# 8          Anam             75              M
# 9           Jai             98              M
# 10         Anil             90              M
# 11         Abhi             78              M

# %%
df['Student Attendance']=[78,90,45,78,89,90,76,98,90,34,56,45]

# %%
df.shape
# Out:
# (12, 4)

# %%
df
# Out:
#    Student Name  Student Marks Student Gender  Student Attendance
# 0           Sam             45              M                  78
# 1          Ravi             90              M                  90
# 2          Amit             36              M                  45
# 3         Vijay             45              M                  78
# 4         Alina             55              F                  89
# 5          Neha             89              F                  90
# 6          Vini             90              F                  76
# 7          Deep             90              F                  98
# 8          Anam             75              M                  90
# 9           Jai             98              M                  34
# 10         Anil             90              M                  56
# 11         Abhi             78              M                  45

# %%
df
# Out:
#    Student Name  Student Marks Student Gender  Student Attendance
# 0           Sam             45              M                  78
# 1          Ravi             90              M                  90
# 2          Amit             36              M                  45
# 3         Vijay             45              M                  78
# 4         Alina             55              F                  89
# 5          Neha             89              F                  90
# 6          Vini             90              F                  76
# 7          Deep             90              F                  98
# 8          Anam             75              M                  90
# 9           Jai             98              M                  34
# 10         Anil             90              M                  56
# 11         Abhi             78              M                  45

# %%
#Remove the column
df.drop('Student Attendance',axis=1,inplace=True)

# %%
df
# Out:
#    Student Name  Student Marks Student Gender
# 0           Sam             45              M
# 1          Ravi             90              M
# 2          Amit             36              M
# 3         Vijay             45              M
# 4         Alina             55              F
# 5          Neha             89              F
# 6          Vini             90              F
# 7          Deep             90              F
# 8          Anam             75              M
# 9           Jai             98              M
# 10         Anil             90              M
# 11         Abhi             78              M

# %%
# drop row from data frame df
df.drop(8,axis=0,inplace=True)

# %%
df
# Out:
#    Student Name  Student Marks Student Gender
# 0           Sam             45              M
# 1          Ravi             90              M
# 2          Amit             36              M
# 3         Vijay             45              M
# 4         Alina             55              F
# 5          Neha             89              F
# 6          Vini             90              F
# 7          Deep             90              F
# 9           Jai             98              M
# 10         Anil             90              M
# 11         Abhi             78              M
